# %% [markdown]
# ## Importing Libraries

# %%
import pandas as pd 
import numpy as np
import spacy
from spacy import displacy
import networkx as nx
import os
import matplotlib.pyplot as plt
import scipy
import re

# %%
import spacy

# Load the language model (corrected)
NER = spacy.load("en_core_web_sm")

# Specify the file path (replace with your actual file path)
file_path = "key_events_20th_century.txt"

# Read the text from the file
with open(file_path, "r", encoding="utf-8") as file:
    text = file.read()

# Process the text with spaCy
doc = NER(text)

# Print named entities
for ent in doc.ents:
    print(ent.text, ent.label_)
# Out:
# The 20th century DATE
# The World Wars ORG
# the Cold War EVENT
# the Space Race ORG
# the World Wide Web EVENT
# the 21st century DATE
# today DATE
# the 20th century DATE
# the beginning of the century DATE
# the 20th century DATE
# The 1900s DATE
# the decade DATE
# 1914 CARDINAL
# the Panama Canal FAC
# 1914 to 1918 DATE
# the First World War EVENT
# World War I EVENT
# 1914–1918 CARDINAL
# World War I Arrest EVENT
# Sarajevo GPE
# Archduke Franz Ferdinand PERSON
# WWI ORG
# The Great War WORK_OF_ART
# July 1914 DATE
# November 1918 DATE
# Sarajevo GPE
# the Austro-Hungarian Empire 's FAC
# Erzherzog Franz Ferdinand PERSON
# Gavrilo Princip PERSON
# Young Bosnia FAC
# the July Crisis EVENT
# the end of July 1914 DATE
# the British Empire GPE
# France GPE
# the Russian Empire GPE
# the Central Powers ORG
# the German Empire GPE
# Austria GPE
# Hungary GPE
# 1 CARDINAL
# 2 CARDINAL
# 1917 DATE
# Russia GPE
# the Central Powers ORG
# Tsar GPE
# Bolsheviks GPE
# Germany GPE
# Russia GPE
# Bolshevik Russia ORG
# Baltic LOC
# Germany GPE
# Kars Oblast LOC
# the South Caucasus LOC
# the Ottoman Empire GPE
# Ukraine GPE
# 3 CARDINAL
# Germany GPE
# Allied ORG
# American NORP
# 1918 DATE
# 4 CARDINAL
# Germans NORP
# 5 CARDINAL
# 6 CARDINAL
# 7 CARDINAL
# British NORP
# 8 CARDINAL
# 9 CARDINAL
# Austria GPE
# World War I EVENT
# 1918 DATE
# the next twenty years DATE
# First ORDINAL
# Germans NORP
# the Treaty of Versailles WORK_OF_ART
# Germans NORP
# 10 CARDINAL
# Germany GPE
# Allied ORG
# Kaiser Wilhelm ORG
# 11 CARDINAL
# Europe LOC
# New states GPE
# Yugoslavia GPE
# Czechoslovakia GPE
# Austro-Hungarian Empire ORG
# 12 CARDINAL
# the League of Nations ORG
# 13 CARDINAL
# Russian Revolution WORK_OF_ART
# Russian Revolution The Russian Revolution of 1917 EVENT
# Tsarist NORP
# Nicholas II PERSON
# Europe LOC
# 14 CARDINAL
# European NORP
# Vladimir Lenin PERSON
# 1924 DATE
# a few years DATE
# Joseph Stalin PERSON
# Leon Trotsky PERSON
# the Soviet Union GPE
# Stalin PERSON
# one CARDINAL
# 15 CARDINAL
# 16 CARDINAL
# socialists NORP
# Stalin PERSON
# 17 CARDINAL
# 1929 DATE
# the Great Depression EVENT
# first ORDINAL
# the Soviet Union's GPE
# the 1930s DATE
# 18 CARDINAL
# Dorothea Lange 's PERSON
# 1936 DATE
# Migrant Mother PERSON
# one CARDINAL
# the Great Depression Main EVENT
# Roaring Twenties EVENT
# World War I EVENT
# the 1920s DATE
# 29 CARDINAL
# the end of the decade DATE
# 19 CARDINAL
# millions CARDINAL
# 20 CARDINAL
# China GPE
# Manchuria GPE
# 7 July 1937 DATE
# Chinese NORP
# Japanese NORP
# the Marco Polo Bridge Incident FAC
# 92 CARDINAL
# Second ORDINAL
# one CARDINAL
# 93 CARDINAL
# Japan GPE
# Shanghai GPE
# Chinese NORP
# Nanjing GPE
# 1937 DATE
# Chinese NORP
# Chongqing GPE
# Chinese NORP
# Changsha GPE
# Guangxi GPE
# 1939 DATE
# Japan GPE
# 94 CARDINAL
# 27 September 1940 DATE
# Japan GPE
# the Tripartite Pact LAW
# Germany GPE
# Italy GPE
# 95 CARDINAL
# Japanese NORP
# ] USS West Virginia PRODUCT
# Pearl Harbor FAC
# 7 December 1941 DATE
# Japan GPE
# American NORP
# Pearl Harbor FAC
# the U.S. Pacific Fleet ORG
# 96 CARDINAL
# The next day DATE
# Roosevelt PERSON
# Infamy Speech ORG
# the United States GPE
# Japan GPE
# World War 2 EVENT
# 97 CARDINAL
# 98 CARDINAL
# Japan GPE
# Thailand GPE
# British NORP
# Malaya GPE
# Singapore GPE
# Hong Kong GPE
# American NORP
# Guam GPE
# Wake Island LOC
# Philippines GPE
# 99 CARDINAL
# The next six months DATE
# Japanese NORP
# Allied ORG
# two years DATE
# Europe LOC
# North Africa GPE
# Japan GPE
# British Burma GPE
# New Guinea GPE
# the Dutch East Indies ORG
# the Solomon Islands GPE
# Bali GPE
# Timor GPE
# 100 CARDINAL
# March 1942, days DATE
# Philippines GPE
# Douglas MacArthur PERSON
# United States Army Forces ORG
# the Far East LOC
# Australia GPE
# 101 CARDINAL
# 19 February 1942 DATE
# Japan GPE
# Australian NORP
# Darwin PERSON
# first ORDINAL
# Australian NORP
# 102 CARDINAL
# early May DATE
# the Battle of the Coral Sea WORK_OF_ART
# first ORDINAL
# Japanese NORP
# 103 CARDINAL
# one month later DATE
# the Battle of Midway ORG
# the US Navy ORG
# Japanese NORP
# The Battle of Midway WORK_OF_ART
# the Pacific Campaign ORG
# 104 CARDINAL
# Japanese NORP
# Japanese NORP
# the United States GPE
# 105 CARDINAL
# this Battle of Midway EVENT
# Solomon Islands GPE
# Japan GPE
# August 1942 DATE
# Allied ORG
# New Guinea GPE
# Guadalcanal GPE
# Milne Bay PERSON
# Buna-Gona PERSON
# 106 CARDINAL
# Allied ORG
# Japanese NORP
# 1937 to 1942 DATE
# the next two years DATE
# Allies ORG
# one CARDINAL
# Japan GPE
# July 1944 DATE
# US GPE
# Guam GPE
# Tinian NORP
# Japan GPE
# Boeing ORG
# B-29 PRODUCT
# 107 CARDINAL
# South-East Asia LOC
# Japanese NORP
# India GPE
# Pacific LOC
# the Battle of the Philippine Sea WORK_OF_ART
# Japan GPE
# 108 CARDINAL
# later October DATE
# American NORP
# Australian NORP
# the Imperial Japanese Navy ORG
# the Battle of Leyte Gulf WORK_OF_ART
# World War II EVENT
# 109 CARDINAL
# Allied ORG
# Japanese NORP
# 110 CARDINAL
# Leyte Gulf FAC
# first ORDINAL
# Japanese NORP
# 111 CARDINAL
# early 1945 DATE
# Americans NORP
# Japanese NORP
# Iwo Jima PERSON
# Tokyo GPE
# six million CARDINAL
# Jews NORP
# 5 million CARDINAL
# Jehovah PERSON
# 136 CARDINAL
# 137 CARDINAL
# 138 CARDINAL
# Soviet NORP
# Allied ORG
# 139 CARDINAL
# 140 CARDINAL
# Germans NORP
# 141 CARDINAL
# Germans NORP
# 142 CARDINAL
# Jews NORP
# German NORP
# Allied ORG
# 143 CARDINAL
# 144 CARDINAL
# The Nuclear Age WORK_OF_ART
# the 1930s DATE
# 145 CARDINAL
# World War II EVENT
# Nazi Germany GPE
# the United States GPE
# the United Kingdom GPE
# the Manhattan Project ORG
# Los Alamos GPE
# New Mexico GPE
# Robert Oppenheimer PERSON
# first ORDINAL
# first ORDINAL
# Trinity ORG
# July 1945 DATE
# 146 CARDINAL
# Germany GPE
# May 1945 DATE
# German NORP
# 147 CARDINAL
# first ORDINAL
# 16 July 1945 DATE
# Allied ORG
# two CARDINAL
# " Little Boy " WORK_OF_ART
# Fat Man WORK_OF_ART
# 148 CARDINAL
# Japanese NORP
# Hiroshima GPE
# Nagasaki GPE
# 6 and 9 August 1945 DATE
# Soviet NORP
# Japanese NORP
# Japanese NORP
# two CARDINAL
# only two CARDINAL
# 149 CARDINAL
# first ORDINAL
# the United States GPE
# the Soviet Union GPE
# first ORDINAL
# August 1949 DATE
# 150 CARDINAL
# 151 CARDINAL
# two CARDINAL
# two CARDINAL
# The United States GPE
# first ORDINAL
# 1950 DATE
# first ORDINAL
# 1952 DATE
# over 400 CARDINAL
# Japan GPE
# The Soviet Union GPE
# 1953 DATE
# 1955 DATE
# 152 CARDINAL
# Mutually Assured Destruction ORG
# the Cold War EVENT
# 153 CARDINAL
# the 1940s DATE
# nine CARDINAL
# today DATE
# the United States GPE
# the Soviet Union GPE
# Russia GPE
# the United Kingdom GPE
# France GPE
# China GPE
# India GPE
# Pakistan GPE
# Israel GPE
# North Korea GPE
# 154 CARDINAL
# South Africa GPE
# six CARDINAL
# the 1980s DATE
# 155 CARDINAL
# Israel GPE
# 156 CARDINAL
# the Nuclear Non-proliferation Treaty ORG
# 1968 DATE
# 157 CARDINAL
# Libya GPE
# Iran GPE
# 158 CARDINAL
# 159 CARDINAL
# World War II EVENT
# Following World War II EVENT
# The United States GPE
# Pearl Harbor FAC
# U.S. GPE
# 160 CARDINAL
# The United States GPE
# the Soviet Union GPE
# two CARDINAL
# 161 CARDINAL
# Europe LOC
# the Marshall Plan LAW
# Germany GPE
# the United States GPE
# Great Britain GPE
# France GPE
# the Soviet Union GPE
# Berlin GPE
# Soviet NORP
# four CARDINAL
# 162 CARDINAL
# Berlin GPE
# 1990 DATE
# Japan GPE
# U.S. GPE
# last seven years DATE
# 1952 DATE
# 163 CARDINAL
# two CARDINAL
# second ORDINAL
# Japan GPE
# third ORDINAL
# West Germany GPE
# 164 CARDINAL
# Allies ORG
# German NORP
# the Nuremberg Trials ORG
# Hitler PERSON
# Hermann Göring PERSON
# the Tokyo War Crime Trial EVENT
# 165 CARDINAL
# the League of Nations ORG
# World War II EVENT
# 166 CARDINAL
# the United Nations ORG
# 24 October 1945 DATE
# San Francisco GPE
# 167 CARDINAL
# Michael Somare PERSON
# first ORDINAL
# Papua New Guinea GPE
# World War II EVENT
# 168 CARDINAL
# 169 CARDINAL
# European NORP
# decades DATE
# Africa LOC
# Asia LOC
# India GPE
# Mahatma Gandhi PERSON
# Indian NORP
# Mohamed Ali Jinnah PERSON
# Muslims NORP
# 1947 DATE
# British NORP
# India GPE
# the Partition of the ORG
# India GPE
# Pakistan GPE
# the People's Republic of Bangladesh GPE
# 1971 DATE
# 170 CARDINAL
# 171 CARDINAL
# Asia LOC
# The United States GPE
# Philippines GPE
# Pacific LOC
# 1946 DATE
# 172 CARDINAL
# French NORP
# Indochina GPE
# French NORP
# the early 1950s DATE
# Laos GPE
# Cambodia GPE
# Vietnam GPE
# 173 CARDINAL
# Africa LOC
# Jomo Kenyatta PERSON
# Kenya GPE
# Kwame Nkrumah PERSON
# Ghana GPE
# 174 CARDINAL
# British Empire GPE
# almost half CARDINAL
# 1968 DATE
# British NORP
# Africa LOC
# Seychelles PERSON
# 1976 DATE
# Between 1956 and 1962 DATE
# almost 20 CARDINAL
# African NORP
# France GPE
# 175 CARDINAL
# Amílcar Cabral ORG
# Portuguese NORP
# Guinea-Bissau ORG
# the mid-1970s DATE
# African NORP
# 176 CARDINAL
# 1946 DATE
# 35 CARDINAL
# the United Nations ORG
# 1970 DATE
# 127 CARDINAL
# 177 CARDINAL
# Africa LOC
# Asia LOC
# 178 CARDINAL
# European NORP
# 179 CARDINAL
# 180 CARDINAL
# the Nigerian Civil War ORG
# the Second Congo War EVENT
# the Second Sudanese Civil War ORG
# the Bangladesh Liberation War ORG
# the 20th century DATE
# 181 CARDINAL
# The Cold War EVENT
# Europe LOC
# Cold War EVENT
# the Yalta Conference EVENT
# Western NORP
# Soviet Union GPE
# Europe LOC
# the next five decades DATE
# 182 CARDINAL
# March 1946 DATE
# Winston Churchill PERSON
# Westminster College ORG
# US GPE
# first ORDINAL
# Soviet NORP
# Western NORP
# Europe LOC
# 183 CARDINAL
# Stettin NORP
# Baltic LOC
# Adriatic NORP
# Central and Eastern Europe LOC
# Warsaw GPE
# Berlin GPE
# Prague GPE
# Vienna GPE
# Budapest GPE
# Belgrade GPE
# Bucharest LOC
# Sofia GPE
# Soviet NORP
# one CARDINAL
# Soviet NORP
# Moscow GPE
# the Soviet Union GPE
# Soviet NORP
# Socialist NORP
# Republics PERSON
# Eastern Poland LOC
# 184 CARDINAL
# Latvia GPE
# the Latvian SSR FAC
# Estonia GPE
# Estonian NORP
# Lithuania GPE
# the Lithuanian SSR ORG
# 185 CARDINAL
# Finland GPE
# 186 CARDINAL
# Romania GPE
# 187 CARDINAL
# Soviet Union GPE
# between 1945 and 1949 DATE
# Yugoslavia GPE
# Albania GPE
# Bulgaria GPE
# Poland GPE
# Romania GPE
# Czechoslovakia GPE
# Hungary GPE
# East Germany GPE
# People's Republics ORG
# 188 CARDINAL
# Soviet NORP
# the next half century DATE
# Soviet NORP
# Europe LOC
# communist NORP
# Mongolia GPE
# China GPE
# North Korea GPE
# Cuba GPE
# Vietnam GPE
# 189 CARDINAL
# Soviet NORP
# Western NORP
# Churchill PERSON
# USSR GPE
# World War II EVENT
# 190 CARDINAL
# two CARDINAL
# the North Atlantic Treaty Organization ORG
# NATO ORG
# 1949 DATE
# 191 CARDINAL
# the Warsaw Pact LAW
# 1955 DATE
# 192 CARDINAL
# Korean War EVENT
# Vietnam War EVENT
# Cuban Missile Crisis ORG
# Two CARDINAL
# the 1950s DATE
# communist NORP
# first ORDINAL
# the Korean War EVENT
# People's Republic of China ORG
# North Korea GPE
# United States GPE
# South Korea GPE
# The Korean Peninsula LOC
# Japanese NORP
# between 1910 and 1945 DATE
# Soviet NORP
# American NORP
# the 38th DATE
# 193 CARDINAL
# South LOC
# 194 CARDINAL
# North Korea's GPE
# South Korea GPE
# 25 June 1950 DATE
# United Nations ORG
# 195 CARDINAL
# Douglas MacArthur PERSON
# the United States GPE
# Canada GPE
# Australia GPE
# Great Britain GPE
# Chinese NORP
# U.N. ORG
# Armistice GPE
# July 1953 DATE
# two CARDINAL
# Koreas GPE
# the century DATE
# 196 CARDINAL
# second ORDINAL
# the Vietnam War EVENT
# third ORDINAL
# the 20th century DATE
# World War I and World War II EVENT
# French NORP
# 21 July 1954 DATE
# Vietnam GPE
# two CARDINAL
# Korea GPE
# the 17th DATE
# North and South LOC
# The United States GPE
# South Vietnam LOC
# 197 CARDINAL
# North LOC
# 198 CARDINAL
# the Gulf of Tonkin Resolution FAC
# North Vietnamese NORP
# American NORP
# U.S. GPE
# 199 CARDINAL
# Truman Doctrine PERSON
# Domino Theory PERSON
# Americans NORP
# the Tet Offensive FAC
# My Lai PERSON
# American NORP
# 200 CARDINAL
# 201 CARDINAL
# U.S. GPE
# Richard Nixon PERSON
# Nixon PERSON
# American NORP
# South Vietnamese NORP
# American NORP
# Nixon PERSON
# 202 CARDINAL
# Cambodia GPE
# South Vietnamese NORP
# 203 CARDINAL
# U.S. GPE
# North Vietnam LOC
# the Paris Peace Accords EVENT
# U.S. GPE
# 204 CARDINAL
# U.S. GPE
# North LOC
# South LOC
# Saigon ORG
# 30 April 1975 DATE
# Vietnam GPE
# Communist NORP
# a year later DATE
# one CARDINAL
# 205 CARDINAL
# 206 CARDINAL
# The Cuban Missile Crisis WORK_OF_ART
# the Cold War EVENT
# Cuba GPE
# Fidel Castro 's PERSON
# the Soviet Union GPE
# 207 CARDINAL
# the United States GPE
# Cuba GPE
# Lockheed ORG
# Soviet NORP
# U.S. GPE
# John F. Kennedy PERSON
# the Soviet Union GPE
# a tense week DATE
# the Soviet Union GPE
# 208 CARDINAL
# 209 CARDINAL
# 1969 DATE
# first ORDINAL
# Moon PERSON
# Cold War EVENT
# the Soviet Union GPE
# United States GPE
# 1957 DATE
# Soviet NORP
# Sputnik PERSON
# 210 CARDINAL
# two CARDINAL
# 211 CARDINAL
# USSR GPE
# first ORDINAL
# Moon PERSON
# 2 CARDINAL
# 212 CARDINAL
# first ORDINAL
# 213 CARDINAL
# U.S. GPE
# Mercury ORG
# Gemini GPE
# Apollo ORG
# Apollo ORG
# 11 CARDINAL
# Moon PERSON
# 20 July 1969 DATE
# 214 CARDINAL
# Five CARDINAL
# Apollo 13 LAW
# 215 CARDINAL
# U.S. GPE
# Soviet NORP
# the early 21st century DATE
# 216 CARDINAL
# 217 CARDINAL
# the Venera 7 and Voyager 2 LAW
# 218 CARDINAL
# later decades DATE
# the American Space Shuttle ORG
# first ORDINAL
# 219 CARDINAL
# Mir FAC
# Skylab PERSON
# 220 CARDINAL
# 221 CARDINAL
# the 1990s DATE
# the International Space Station ORG
# the end of the century DATE
# the United States GPE
# Europe LOC
# Russia GPE
# Japan GPE
# Canada GPE
# 222 CARDINAL
# the Cold War EVENT
# 1989 DATE
# the Berlin Wall FAC
# West LOC
# East Berlin GPE
# Cold War EVENT
# 1985-1991 DATE
# the 1980s DATE
# the Soviet Union GPE
# Sino-Soviet NORP
# USSR GPE
# the People's Republic of China GPE
# 223 CARDINAL
# U.S. GPE
# Mikhail Gorbachev PERSON
# 224 CARDINAL
# Solidarity ORG
# 225 CARDINAL
# the Berlin Wall FAC
# 226 CARDINAL
# Soviet NORP
# Lithuania GPE
# 227 CARDINAL
# Gorbachev PERSON
# Communist Party ORG
# Boris Yeltsin PERSON
# Russia GPE
# 228 CARDINAL
# 26 December 1991 DATE
# the Soviet Union GPE
# Cold War EVENT
# 229 CARDINAL
# first ORDINAL
# World War II EVENT
# 230 CARDINAL
# at least 20 CARDINAL
# 231 CARDINAL
# 232 CARDINAL
# 233 CARDINAL
# 234 CARDINAL
# 2 CARDINAL
# Wrens The PERSON
# 235 CARDINAL
# 236 CARDINAL
# thousands CARDINAL
# the Apple II LAW
# 237 CARDINAL
# 238 CARDINAL
# IBM ORG
# IBM Personal Computer ORG
# IBM ORG
# third ORDINAL
# 239 CARDINAL
# Compaq ORG
# BIOS ORG
# 240 CARDINAL
# 241 CARDINAL
# Microsoft ORG
# 242 CARDINAL
# The 1980s DATE
# the Information Age PRODUCT
# The U.S. Government ORG
# 243 CARDINAL
# Richard Stallman PERSON
# the Free Software Foundation ORG
# 244 CARDINAL
# first ORDINAL
# Pong and Space Invaders ORG
# 245 CARDINAL
# 246 CARDINAL
# 247 CARDINAL
# first ORDINAL
# IBM ORG
# two CARDINAL
# the Bulletin Board ORG
# 248 CARDINAL
# DARPA ORG
# TCP ORG
# 249 CARDINAL
# Al Gore PERSON
# 250 CARDINAL
# 251 CARDINAL
# the File Transfer Protocol ORG
# FTP ORG
# Bulletin Boards PERSON
# Compuserve and America Online ORG
# Tim Berners-Lee PERSON
# Vannevar Bush 's PERSON
# the World Wide Web EVENT
# 252 CARDINAL
# The Web WORK_OF_ART
# HTML ORG
# 253 CARDINAL
# 254 CARDINAL
# 255 CARDINAL
# the century DATE
# Y2K PERSON
# World ORG
# the end of the century DATE
# 1990s DATE
# the end of the century DATE
# daily DATE
# Europe LOC
# first ORDINAL
# Indian NORP
# sixth ORDINAL
# the end of the century DATE
# first ORDINAL
# centuries DATE
# China GPE
# a fifth CARDINAL
# West LOC
# East LOC
# the Cold War EVENT
# Africa LOC
# centuries DATE
# 256 CARDINAL
# the 21st century DATE
# HadCM3 NORP
# 3.0 CARDINAL
# 5.4 °F DATE
# second ORDINAL
# first ORDINAL
# the 19th century DATE
# World War I. EVENT
# 257 CARDINAL
# US GPE
# Americanization PERSON
# 258 CARDINAL
# anti-Western NORP
# anti-American NORP
# the Middle East LOC
# 259 CARDINAL
# China GPE
# India GPE
# West LOC
# 260 CARDINAL
# the late century DATE
# Oklahoma City GPE
# 168 CARDINAL
# Kim Jong-il PERSON
# North Korea GPE
# 261 CARDINAL
# West Nile GPE
# 262 CARDINAL
# 263 CARDINAL
# Millions CARDINAL
# Africa LOC
# 264 CARDINAL
# several decades DATE
# 265 CARDINAL
# 266 CARDINAL
# the 20th century’s DATE
# New Year's Eve EVENT
# 1999 DATE
# New Year's Day 2000 EVENT
# the turn of the millennium DATE
# the 20th century ended DATE
# New Year's Eve 2000 EVENT
# the 21st century DATE
# New Year's Day 2001 EVENT
# the 20th century DATE
# the 20th century DATE
# the 20th century DATE
# 1901-2000 20th century DATE
# 20th-century DATE
# 20th-century DATE
# Robert PERSON
# September 2018 DATE
# The Major Alliances of ORG
# World War I Began as Hope for Mutual Protection EVENT
# 11 December 2018 DATE
# the First World War EVENT
# 11 December 2018 DATE
# WWI Centennial: The Treaty of Brest-Litovsk WORK_OF_ART
# 5 March 2018 DATE
# 11 December 2018 DATE
# Anthony, Maria ( PERSON
# 6 August 2018 DATE
# Amiens to Armistice WORK_OF_ART
# The Hundred Days Offensive EVENT
# Imperial War Museums ORG
# 11 December 2018 DATE
# 11 December 2018 DATE
# Mason ORG
# Amanda ORG
# 9 January 2018 DATE
# The U-Boat Campaign ORG
# Britain GPE
# Imperial War Museums ORG
# 11 December 2018 DATE
# the day DATE
# first ORDINAL
# 28 April 2016 DATE
# 11 December 2018 DATE
# Brosnan PERSON
# Matt PERSON
# 8 January 2018 DATE
# The First World War EVENT
# Imperial War Museums ORG
# 11 December 2018 DATE
# Dunleavy ORG
# Brian PERSON
# Life in the Trenches of World War I WORK_OF_ART
# 11 December 2018 DATE
# The National Archives Learning Curve ORG
# The Great War EVENT
# 11 December 2018 DATE
# First ORDINAL
# 10-17 November 1918 DATE
# 11 December 2018 DATE
# Crumbling of Empires and Emerging States WORK_OF_ART
# Czechoslovakia GPE
# Yugoslavia GPE
# the First World War (WW1 EVENT
# 11 December 2018 DATE
# BBC ORG
# The League of Nations ORG
# the United Nations ORG
# 11 December 2018 DATE
# Schmitt PERSON
# Hans A. PERSON
# Virginia GPE
# University of ( ORG
# 1988 DATE
# Between War and Revolution, 1916 23 EVENT
# Charlottesville ORG
# University of Virginia Press ORG
# 238 CARDINAL
# 9780813911533 DATE
# On the Final Victory of Socialism in the U.S.S.R. WORK_OF_ART
# 11 December 2018 DATE
# Collectivization and Industrialization WORK_OF_ART
# 11 December 2018 DATE
# 2012 DATE
# The Foreign Communist Experience WORK_OF_ART
# Stalin PERSON
# USSR GPE
# Honors Project ORG
# 147 CARDINAL
# 3 CARDINAL
# Politics in The Great Depression WORK_OF_ART
# 11 December 2018 DATE
# Marks ORG
# Julie PERSON
# 1929 DATE
# Decolonization of Asia and Africa WORK_OF_ART
# 1945–1960 CARDINAL
# 18 December 2018 DATE
# Fisher PERSON
# Max PERSON
# September 2012 DATE
# The Dividing of a Continent: Africa's WORK_OF_ART
# Atlantic LOC
# 20 December 2018 DATE
# Mahmud ORG
# Tayyab ORG
# 28 April 2010 DATE
# Colonial Cartographies ORG
# Postcolonial Borders ORG
# Enduring Failures of ORG
# Afghanistan GPE
# Brooklyn Journal of International Law ORG
# 20 CARDINAL
# 1 CARDINAL
# 1 CARDINAL
# 1596835 DATE
# Hyde PERSON
# Tim PERSON
# 13 July 2016 DATE
# Europeans NORP
# Africa LOC
# American Economic Association ORG
# 18 December 2018 DATE
# 7 Civil Wars WORK_OF_ART
# Africa LOC
# Africa LOC
# 14 March 2017 DATE
# 20 December 2018 DATE
# The Yalta Conference - The Cold War WORK_OF_ART
# 1945–1989 DATE
# 20 December 2018 DATE
# Churchill, Winston ORG
# March 1946 DATE
# The Sinews of Peace ('Iron Curtain Speech' WORK_OF_ART
# The International Churchill Society ORG
# 20 December 2018 DATE
# Roberts PERSON
# Geoffrey PERSON
# 2006 DATE
# Stalin PERSON
# World War to Cold War EVENT
# 1939-1953 DATE
# Yale University Press ORG
# 43 CARDINAL
# 9780300112047 DATE
# Smulkstys PERSON
# Julius PERSON
# Summer 1968 DATE
# The Incorporation of the Baltic States WORK_OF_ART
# the Soviet Union GPE
# 14 CARDINAL
# 2 CARDINAL
# ISSN ORG
# 0024-5089 DATE
# The End of WWII WORK_OF_ART
# the Division of Europe ORG
# Center for European Studies ORG
# 20 December 2018 DATE
# King PERSON
# Charles PERSON
# Moldovans NORP
# Romania GPE
# Russia GPE
# the Politics of Culture ORG
# pp PERSON
# 94 DATE
# 9780817997922 DATE
# Wood ORG
# Alan PERSON
# 2005 DATE
# Stalin PERSON
# Stalinism NORP
# 2nd ORDINAL
# London GPE
# New York GPE
# 63 CARDINAL
# 9780415307321 DATE
# Englund PERSON
# Will PERSON
# 26 October 2016 DATE
# Red Century: From the 'October Revolution' WORK_OF_ART
# 1917 DATE
# North Korea GPE
# one CARDINAL
# The Washington Post ORG
# 27 October 2017 DATE
# 20 December 2018 DATE
# Fenton PERSON
# Ben PERSON
# 1 October 1998 DATE
# Red Army ORG
# The Daily Telegraph ORG
# 20 April 2016 DATE
# 20 December 2018 DATE
# North Atlantic Treaty Organization ORG
# NATO ORG
# 1949 DATE
# 20 December 2018 DATE
# Rosenberg PERSON
# Matt PERSON
# 30 September 2018 DATE
# The Warsaw Pact History and Members WORK_OF_ART
# 20 December 2018 DATE
# McDonough ORG
# Richard PERSON
# 13 June 2018 DATE
# A Short History Of The Korean War WORK_OF_ART
# Imperial War Museums ORG
# 20 December 2018 DATE
# Stack ORG
# Liam PERSON
# 1 January 2018 DATE
# Korean War WORK_OF_ART
# Forgotten' Conflict That Shaped the Modern World WORK_OF_ART
# The New York Times ORG
# ISSN 0362-4331 ORG
# 20 December 2018 DATE
# Hastings PERSON
# Max PERSON
# 1987 DATE
# Korean War ORG
# New York GPE
# Simon PERSON
# Schuster Paperbacks PERSON
# 55 DATE
# 9780671668341 DATE
# Bruce PERSON
# Robert Z. PERSON
# 20 July 2018 DATE
# 50 Years Ago DATE
# Apollo 11 Was LAW
# Space.com ORG
# 20 December 2018 DATE
# The Apollo Program WORK_OF_ART
# 1963 - 1972 DATE
# NASA ORG
# 20 December 2018 DATE
# Ingham, Lucy ORG
# 16 January 2018 DATE
# Soviet NORP
# first ORDINAL
# 20 December 2018 DATE
# Keldysh PERSON
# M.V. GPE
# April 1977 DATE
# the Venera 9 PRODUCT
# Venera 10 LAW
# Icarus PERSON
# 30 CARDINAL
# 4 CARDINAL
# 605 CARDINAL
# 625 CARDINAL
# 1977Icar...30 CARDINAL
# 10.1016/0019-1035(77)90085 CARDINAL
# ISSN ORG
# 0019-1035 DATE
# Howell ORG
# Elizabeth PERSON
# 10 December 2018 DATE
# Voyager 2: PRODUCT
# Space.com ORG
# 20 December 2018 DATE
# Sharp PERSON
# Tim PERSON
# 11 December 2017 DATE
# Space Shuttle PERSON
# Space.com ORG
# 20 December 2018 DATE
# Ferreira GPE
# Becky GPE
# 19 February 2016 DATE
# The Mir Space Station Was a Marvel WORK_OF_ART
# Clusterfuck GPE
# 20 December 2018 DATE
# Torchinsky, Jason ORG
# 14 May 2013 DATE
# Skylab PERSON
# America GPE
# First And Best Home In Space ORG
# Jalopnik PERSON
# 20 December 2018 DATE
# Science & Innovation ORG
# 15 October 2009 DATE
# 26 April 2018 DATE
# 20 December 2018 DATE
# Farley ORG
# Robert PERSON
# 6 March 2017 DATE
# Sino-Soviet NORP
# Split Borne of Ideology PERSON
# Diplomat PRODUCT
# 20 December 2018 DATE
# Siegelbaum, ORG
# Lewis PERSON
# 22 June 2015 DATE
# Perestroika and Glasnost WORK_OF_ART
# Seventeen CARDINAL
# Soviet NORP
# 20 December 2018 DATE
# Kramer PERSON
# Mark PERSON
# 12 December 2011 DATE
# The New York Times ORG
# ISSN 0362-4331 ORG
# 20 December 2018 DATE
# Bonnell PERSON
# Andrew PERSON
# 3 October 2018 DATE
# the Berlin Wall FAC
# 20 December 2018 DATE
# Egorov GPE
# Boris PERSON
# 23 August 2018 DATE
# Baltic LOC
# the Soviet Union GPE
# 20 December 2018 DATE
# Sandford, Daniel ( ORG
# 20 August 2011 DATE
# Boris Yeltsin PERSON
# 1991 DATE
# BBC News ORG
# 20 December 2018 DATE
# Schmemann, Serge ORG
# 26 December 1991 DATE
# THE SOVIET UNION GPE
# The Soviet State GPE
# The New York Times ORG
# ISSN 0362-4331 ORG
# 20 December 2018 DATE
# Flowers PERSON
# Thomas H. PERSON
# July 1983 DATE
# The Design of Colossus WORK_OF_ART
# Foreword ORG
# Howard Campaigne PERSON
# IEEE Ann PERSON
# 3 CARDINAL
# 239 CARDINAL
# 252 CARDINAL
# 10.1109/MAHC.1983.10079 DATE
# ISSN ORG
# S2CID 39816473 CARDINAL
# Moore PERSON
# Gordon E. PERSON
# October 2006 DATE
# 1965 DATE
# Cramming More Components onto Integrated Circuits WORK_OF_ART
# IEEE Solid-State PERSON
# Circuits Newsletter WORK_OF_ART
# 11 CARDINAL
# 3 CARDINAL
# 33 CARDINAL
# 35 DATE
# 10.1109/N-SSC.2006.4785860 CARDINAL
# S2CID 24300252 DATE
# Szczepaniak PERSON
# John PERSON
# May 2014 DATE
# BASIC ORG
# 50th ORDINAL
# 27 December 2018 DATE
# The History of the Computer Mouse - Computing History WORK_OF_ART
# 27 December 2018 DATE
# Memory & Storage WORK_OF_ART
# Computer History Museum ORG
# 27 December 2018 DATE
# Kellaway GPE
# Lucy PERSON
# 1 August 2013 DATE
# BBC News ORG
# 27 December 2018 DATE
# Alfredo GPE
# David PERSON
# 26 September 2017 DATE
# The History of Computers in Business WORK_OF_ART
# 27 December 2018 DATE
# Lean PERSON
# Tom PERSON
# February 2016 DATE
# 1980s DATE
# Bloomsbury Publishing ORG
# 9781472918352 DATE
# Denise PERSON
# May 2011 DATE
# Archive Gallery: The Rise of Personal Computers WORK_OF_ART
# Maher PERSON
# Jimmy PERSON
# 30 June 2017 DATE
# IBM ORG
# one CARDINAL
# the century DATE
# 27 December 2018 DATE
# McCullough PERSON
# Brian PERSON
# 29 May 2014 DATE
# Behind 'Halt and Catch Fire' WORK_OF_ART
# Compaq ORG
# 27 December 2018 DATE
# McCullough PERSON
# Brian PERSON
# 26 May 2014 DATE
# The Incredible True Story Behind AMC's WORK_OF_ART
# Halt And Catch Fire ORG
# IBM ORG
# Created An Empire ORG
# 27 December 2018 DATE
# Musolf PERSON
# Nell ORG
# 2008 DATE
# Microsoft ORG
# The Creative Company ORG
# 9781583416075 DATE
# Benson ORG
# Flook PERSON
# Diehr ORG
# Bilski GPE
# Prometheus PERSON
# 27 December 2018 DATE
# Williams PERSON
# Sam PERSON
# 2010 DATE
# 2.0 CARDINAL
# Richard Stallman PERSON
# the Free Software Revolution ORG
# Free Software Foundation ORG
# 9780983159216 DATE
# Kent PERSON
# Steve L. PERSON
# 2001 DATE
# The Ultimate History of Video Games ORG
# Pong GPE
# Pokémon PERSON
# Craze ORG
# 9780761536437 DATE
# Stanton ORG
# Richard PERSON
# 14 July 2015 DATE
# Video Games EVENT
# 9780762456154 DATE
# Evolution of Home Video Game Consoles WORK_OF_ART
# 1967 - 2011 DATE
# Hongkiat GPE
# 13 April 2011 DATE
# 27 December 2018 DATE
# Edwards PERSON
# Benj PERSON
# November 2016 DATE
# The Lost Civilization of Dial-Up Bulletin Board Systems WORK_OF_ART
# Atlantic LOC
# 27 December 2018 DATE
# Cerf PERSON
# Vint PERSON
# A Brief History of the Internet & Related Networks WORK_OF_ART
# 27 December 2018 DATE
# Lee PERSON
# Timothy B. PERSON
# 16 June 2014 DATE
# Vox ORG
# 27 December 2018 DATE
# Flanagan PERSON
# Graham PERSON
# Al Gore PERSON
# Business Insider ORG
# 27 December 2018 DATE
# Wright PERSON
# Alex PERSON
# 22 May 2014 DATE
# The Secret History of Hypertext WORK_OF_ART
# Atlantic LOC
# 27 December 2018 DATE
# Motley Fool Staff ORG
# 3 July 2018 DATE
# 25 Years DATE
# The Motley Fool ORG
# 27 December 2018 DATE
# Estrada GPE
# Susan PERSON
# 1992 DATE
# 2 CARDINAL
# 3 CARDINAL
# 24 DATE
# 28 CARDINAL
# 10.1108/eb047265 CARDINAL
# Where Are They Now: WORK_OF_ART
# 17 CARDINAL
# CB Insights Research ORG
# 14 CARDINAL
# September 2016 DATE
# 27 December 2018 DATE
# Lukacs PERSON
# John PERSON
# 1993 DATE
# The end of the twentieth century DATE
# Ticknor & Fields ORG
# 9780395584729 DATE
# Johnson PERSON
# 2008 DATE
# The Three Waves of Globalisation - Nordregio WORK_OF_ART
# 29 December 2018 DATE
# Fraser GPE
# Nick PERSON
# November 2014 DATE
# Guardian ORG
# ISSN ORG
# 29 December 2018 DATE
# Corstange ORG
# Daniel PERSON
# January 2016 DATE
# Anti-American Behavior ORG
# the Middle East LOC
# a Field Experiment LAW
# Lebanon GPE
# The Journal of Politics ORG
# 78 CARDINAL
# 1 CARDINAL
# 311 CARDINAL
# 325 CARDINAL
# 10.1086/683372 CARDINAL
# S2CID 146972591 DATE
# Journalist's Resource ORG
# Lam PERSON
# Peng Er PERSON
# Lim PERSON
# Tai-Wei PERSON
# 2009 DATE
# India GPE
# New Asian NORP
# Singapore GPE
# World Scientific ORG
# 10.1142/7381 CARDINAL
# 9789814280334 DATE
# North and South Korean WORK_OF_ART
# Guardian ORG
# Associated Press ORG
# 13 June 2000 DATE
# ISSN ORG
# 29 December 2018 DATE
# Lee PERSON
# S. H. PERSON
# September 2003 DATE
# Hong Kong GPE
# Journal of Epidemiology & Community Health ORG
# 57 CARDINAL
# 9 CARDINAL
# 652 CARDINAL
# 654 CARDINAL
# 10.1136 CARDINAL
# ISSN ORG
# 1470-2738 DATE
# PMC ORG
# 1732583 DATE
# Sejvar PERSON
# James J. PERSON
# 2003 DATE
# The Ochsner Journal ORG
# 5 CARDINAL
# 3 CARDINAL
# ISSN ORG
# 1524-5012 DATE
# PMC ORG
# 3111838 DATE
# Kagaayi PERSON
# Joseph PERSON
# Serwadda PERSON
# David PERSON
# August 2016 DATE
# The History of the HIV/AIDS Epidemic WORK_OF_ART
# Africa LOC
# 13 CARDINAL
# 4 CARDINAL
# 187 CARDINAL
# 193 CARDINAL
# 10.1007 CARDINAL
# ISSN ORG
# 1548-3576 DATE
# S2CID 8292731 DATE
# Rich PERSON
# Nathaniel PERSON
# 5 August 2018 DATE
# The New York Times Magazine ORG
# pp PERSON
# 4–. CARDINAL
# ISSN ORG
# 15 January 2022 DATE
# Henson PERSON
# Robert PERSON
# 11 March 2011 DATE
# the Kyoto Protocol LAW
# Guardian ORG
# ISSN ORG
# 29 December 2018 DATE
# UNESCO ORG
# 28 February 2008 DATE
# The Twentieth Century ORG
# Humanity NORP
# 600 CARDINAL
# 978 CARDINAL
# Wikimedia Commons ORG
# the 20th century DATE
# 20th ORDINAL
# Century Research Project ORG
# 26 CARDINAL
# February 2012 DATE
# the Twentieth Century ORG
# 6 CARDINAL
# February 2012 DATE
# the 20th Century DATE
# 17 January 2005 DATE
# Centuries DATE
# Millennium Century BC ORG
# BCE ORG
# 4th ORDINAL
# 40th 39th 38th 37th 36th 35th 34th DATE
# 33rd 32nd 31st 3rd 30th 29th 28th 27th 26th 25th 24th DATE
# 23rd 22nd 21st DATE
# 18th 17th 16th 15th 14th 13th 12th 11th 1st DATE
# 10th 9th 8th DATE
# 7th ORDINAL
# 6th ORDINAL
# 5th ORDINAL
# 2nd 1st AD DATE
# 1st 1st DATE
# 2nd ORDINAL
# 3rd ORDINAL
# 4th ORDINAL
# 5th ORDINAL
# 6th ORDINAL
# 7th ORDINAL
# 9th ORDINAL
# 11th 12th 13th 14th DATE
# 3rd ORDINAL
# 21st 22nd 23rd 24th 25th 26th DATE
# 27th 28th 29th 30th DATE
# the 20th century DATE
# 1900s DATE
# 1930s 1940s 1950s 1960s DATE
# 1970s 1980s DATE
# Art Christianity Literature Music ORG
# 1970s 1980s DATE
# 1990s DATE
# Theatre Lists State ORG
# 1901–1950 1951–2000 DATE
# Riots Solar PERSON
# Volcanic ORG

# %%
# Load the text

with open('key_events_20th_century.txt', 'r', errors='ignore') as file: 
   text = file.read().replace( '\n', ' ')

doc = NER(text)

# %%
# Visualize identified entities

displacy.render(doc[273:20000], style = "ent", jupyter = True)
# Out:
# <span class="tex2jax_ignore"><div class="entities" style="line-height: 2.5; direction: ltr">liberation movement. After a period of diplomatic and military escalation known as
# <mark class="entity" style="background: #ffeb80; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the July Crisis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">EVENT</span>
# </mark>
#  , by
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the end of July 1914
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  two coalitions were at war: the Allies, comprised initially of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the British Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     France
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  , and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Russian Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ; and
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  , comprised initially of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the German Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  and
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Austria
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# -
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Hungary
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . [
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ] [
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     2
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  ] In
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     1917
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
# ,
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  ended hostile actions against
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Central Powers
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  after the fall of the
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Tsar
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . The
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolsheviks
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  negotiated the Treaty of Brest-Litovsk with
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , although it was a huge cost to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# . In the treaty,
# <mark class="entity" style="background: #7aecec; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Bolshevik Russia
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">ORG</span>
# </mark>
#  ceded the
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Baltic
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  states to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Germany
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
# , and its province of
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     Kars Oblast
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  in
# <mark class="entity" style="background: #ff9561; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the South Caucasus
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">LOC</span>
# </mark>
#  to
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     the Ottoman Empire
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  . It also recognized the independence of
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; bor

# %% [markdown]
# ## Comments on question 4

# %% [markdown]
# The text requires a bit of wrangling for the Countries appearing by their first names, making it easy to compare with the names on the scraped Countries list. By all standards, the names of countries are the same in both documents.
# I have also observed that the countries have been categorized as "GPE", years as "DATE", and names of persons as "PERSON" making it easy to split the sentence entities.

# %% [markdown]
# ## creating a dataframe from a list of dictionaries

# %%
df_sentences = []

# Loop through sentences, get entity list for each sentence
for sent in doc.sents:
       entity_list = [ent.text for ent in sent.ents]
       df_sentences.append({"sentence": sent, "entities": entity_list})

df_sentences = pd.DataFrame(df_sentences)

# %%
df_sentences.head(20)
# Out:
#                                              sentence  \
# 0   (The, 20th, century, changed, the, world, in, ...
# 1   (The, World, Wars, sparked, tension, between, ...
# 2   (These, advancements, have, played, a, signifi...
# 3   (Historic, events, in, the, 20th, century, [, ...
# 4   (The, 1900s, saw, the, decade, herald, a, seri...
# 5   (1914, saw, the, completion, of, the, Panama, ...
# 6   (From, 1914, to, 1918, ,, the, First, World, W...
# 7   (", The, war, to, end, all, wars, ", :, World,...
# 8   (The, war, was, precipitated, by, the, Assassi...
# 9   (After, a, period, of, diplomatic, and, milita...
# 10  ([, 1, ], [, 2, ], In, 1917, ,, Russia, ended,...
# 11  (The, Bolsheviks, negotiated, the, Treaty, of,...
# 12  (In, the, treaty, ,, Bolshevik, Russia, ceded,...
# 13  (It, also, recognized, the, independence, of, ...
# 14  ([, 3, ], Although, Germany, shifted, huge, fo...
# 15  ([, 4, ], The, war, itself, was, also, a, chan...
# 16  (The, Germans, introduced, the, machine, gun, ...
# 17  ([, 7, ], The, British, first, used, the, tank...
# 18  ([, 8, ], Both, sides, had, a, chance, to, tes...
# 19  (It, was, widely, believed, that, the, war, wo...
#
#                                              entities
# 0                                  [The 20th century]
# 1   [The World Wars, the Cold War, the Space Race,...
# 2                           [the 21st century, today]
# 3   [the 20th century, the beginning of the centur...
# 4                             [The 1900s, the decade]
# 5                            [1914, the Panama Canal]
# 6                 [1914 to 1918, the First World War]
# 7   [World War I, World War I Arrest, Sarajevo, Ar...
# 8   [Sarajevo, the Austro-Hungarian Empire 's, Erz...
# 9   [the July Crisis, the end of July 1914, the Br...
# 10     [1, 2, 1917, Russia, the Central Powers, Tsar]
# 11                      [Bolsheviks, Germany, Russia]
# 12  [Bolshevik Russia, Baltic, Germany, Kars Oblas...
# 13                                          [Ukraine]
# 14               [3, Germany, Allied, American, 1918]
# 15                                                [4]
# 16                                    [Germans, 5, 6]
# 17                                       [7, British]
# 18                                                [8]
# 19                                                 []

# %% [markdown]
# ## Filtering Data Using the Countries

# %%
# Import txt file and read the countries
with open('Countries_List.txt', 'r', errors='ignore') as file: 
    # Read all lines and strip any extra whitespace
    data = file.read().strip()

# Split the data into a list by newlines
countries_list = data.split('\n')

# Optionally, you can strip leading/trailing spaces from each country
countries_list = [country.strip() for country in countries_list]

# Print the resulting list
print(countries_list)
# Out:
# ['country_name', '1\t Afghanistan', '2\t  Albania', '3\t  Algeria', '4\t  Andorra', '5\t  Angola', '6\t  Antigua and Barbuda', '7\t  Argentina', '8\t  Armenia', '9\t  Australia', '10\t  Austria', '11\t  Azerbaijan', '12\t" Bahamas, The "', '13\t  Bahrain', '14\t  Bangladesh', '15\t  Barbados', '16\t  Belarus', '17\t  Belgium', '18\t  Belize', '19\t  Benin', '20\t  Bhutan', '21\t  Bolivia', '22\t  Bosnia and Herzegovina', '23\t  Botswana', '24\t  Brazil', '25\t  Brunei', '26\t  Bulgaria', '27\t  Burkina Faso', '28\t  Burundi', '29\t Cambodia', '30\t  Cameroon', '31\t  Canada', '32\t  Cape Verde', '33\t  Central African Republic', '34\t  Chad', '35\t  Chile', '36\t"  China, People\'s Republic of "', '37\t  Colombia', '38\t  Comoros', '39\t"  Congo, Democratic Republic of the "', '40\t"  Congo, Republic of the "', '41\t  Costa Rica', '42\t  Croatia', '43\t  Cuba', '44\t  Cyprus', '45\t  Czech Republic', '46\t  Denmark', '47\t   Djibouti', '48\t   Dominica', '49\t   Dominican Republic', '50\t  East Timor', '51\t   Ecuador', '52\t   Egypt', '53\t   El Salvador', '54\t   Equatorial Guinea', '55\t   Eritrea', '56\t   Estonia', '57\t   Eswatini', '58\t   Ethiopia', '59\t  Fiji', '60\t   Finland', '61\t   France', '62\t  Gabon', '63\t"   Gambia, The "', '64\t   Georgia', '65\t   Germany', '66\t   Ghana', '67\t   Greece', '68\t   Grenada', '69\t   Guatemala', '70\t   Guinea', '71\t   Guinea', '72\tBissau', '73\t   Guyana', '74\t  Haiti', '75\t   Honduras', '76\t   Hungary', '77\t  Iceland', '78\t   India', '79\t   Indonesia', '80\t   Iran', '81\t   Iraq', '82\t   Ireland', '83\t   Israel', '84\t   Italy', '85\t   Ivory Coast', '86\t  Jamaica', '87\t   Japan', '88\t   Jordan', '89\t  Kazakhstan', '90\t   Kenya', '91\t   Kiribati', '92\t"   Korea, North "', '93\t"   Korea, South "', '94\t   Kuwait', '95\t   Kyrgyzstan', '96\t  Laos', '97\t   Latvia', '98\t   Lebanon', '99\t   Lesotho', '100\t   Liberia', '101\t   Libya', '102\t   Liechtenstein', '103\t   Lithuania', '104\t   Luxembourg', '105\t  Madagascar', '106\t   Malawi', '107\t   Malaysia', '108\t   Maldives', '109\t   Mali', '110\t   Malta', '111\t   Marshall Islands', '112\t   Mauritania', '113\t   Mauritius', '114\t   Mexico', '115\t"   Micronesia, Federated States of "', '116\t   Moldova', '117\t   Monaco', '118\t   Mongolia', '119\t   Montenegro', '120\t   Morocco', '121\t   Mozambique', '122\t   Myanmar', '123\t  Namibia', '124\t   Nauru', '125\t     Nepal', '126\t   Netherlands', '127\t   New Zealand', '128\t   Nicaragua', '129\t   Niger', '130\t   Nigeria', '131\t   North Macedonia', '132\t   Norway', '133\t  Oman', '134\t  Pakistan', '135\t   Palau', '136\t   Palestine', '137\t   Panama', '138\t   Papua New Guinea', '139\t   Paraguay', '140\t   Peru', '141\t   Philippines', '142\t   Poland', '143\t   Portugal', '144\t  Qatar', '145\t  Romania', '146\t   Russia', '147\t   Rwanda', '148\t  Saint Kitts and Nevis', '149\t   Saint Lucia', '150\t   Saint Vincent and the Grenadines', '151\t   Samoa', '152\t   San Marino', '153\t   S?œo Tom?? and Pr??ncipe', '154\t   Saudi Arabia', '155\t   Senegal', '156\t   Serbia', '157\t   Seychelles', '158\t   Sierra Leone', '159\t   Singapore', '160\t   Slovakia', '161\t   Slovenia', '162\t   Solomon Islands', '163\t   Somalia', '164\t   South Africa', '165\t   South Sudan', '166\t   Spain', '167\t   Sri Lanka', '168\t   Sudan', '169\t   Suriname', '170\t   Sweden', '171\t    Switzerland', '172\t   Syria', '173\t  Tajikistan', '174\t   Tanzania', '175\t   Thailand', '176\t   Togo', '177\t   Tonga', '178\t   Trinidad and Tobago', '179\t   Tunisia', '180\t   Turkey', '181\t   Turkmenistan', '182\t   Tuvalu', '183\t  Uganda', '184\t   Ukraine', '185\t   United Arab Emirates', '186\t   United Kingdom', '187\t   United States', '188\t   Uruguay', '189\t   Uzbekistan', '190\t  Vanuatu', '191\t    Vatican City (Holy See)', '192\t   Venezuela', '193\t   Vietnam', '194\t  Yemen', '195\t  Zambia', '196\t   Zimbabwe', '197\t  Abkhazia', '198\t   Artsakh' ...

# %%
# Your original data (list of country names with indices)
country_list_raw = [
    '1\t Afghanistan', '2\t  Albania', '3\t  Algeria', '4\t  Andorra', '5\t  Angola', 
    '6\t  Antigua and Barbuda', '7\t  Argentina', '8\t  Armenia', '9\t  Australia', 
    '10\t  Austria', '11\t  Azerbaijan', '12\t" Bahamas, The "', '13\t  Bahrain', 
    '14\t  Bangladesh', '15\t  Barbados', '16\t  Belarus', '17\t  Belgium', '18\t  Belize', 
    '19\t  Benin', '20\t  Bhutan', '21\t  Bolivia', '22\t  Bosnia and Herzegovina', 
    '23\t  Botswana', '24\t  Brazil', '25\t  Brunei', '26\t  Bulgaria', '27\t  Burkina Faso', 
    '28\t  Burundi', '29\t Cambodia', '30\t  Cameroon', '31\t  Canada', '32\t  Cape Verde', 
    '33\t  Central African Republic', '34\t  Chad', '35\t  Chile', '36\t"  China, People\'s Republic of "', 
    '37\t  Colombia', '38\t  Comoros', '39\t"  Congo, Democratic Republic of the "', 
    '40\t"  Congo, Republic of the "', '41\t  Costa Rica', '42\t  Croatia', '43\t  Cuba', 
    '44\t  Cyprus', '45\t  Czech Republic', '46\t  Denmark', '47\t   Djibouti', '48\t   Dominica', 
    '49\t   Dominican Republic', '50\t  East Timor', '51\t   Ecuador', '52\t   Egypt', 
    '53\t   El Salvador', '54\t   Equatorial Guinea', '55\t   Eritrea', '56\t   Estonia', 
    '57\t   Eswatini', '58\t   Ethiopia', '59\t  Fiji', '60\t   Finland', '61\t   France', 
    '62\t  Gabon', '63\t"   Gambia, The "', '64\t   Georgia', '65\t   Germany', '66\t   Ghana', 
    '67\t   Greece', '68\t   Grenada', '69\t   Guatemala', '70\t   Guinea', '71\t   Guinea', 
    '72\tBissau', '73\t   Guyana', '74\t  Haiti', '75\t   Honduras', '76\t   Hungary', 
    '77\t  Iceland', '78\t   India', '79\t   Indonesia', '80\t   Iran', '81\t   Iraq', '82\t   Ireland', 
    '83\t   Israel', '84\t   Italy', '85\t   Ivory Coast', '86\t  Jamaica', '87\t   Japan', 
    '88\t   Jordan', '89\t  Kazakhstan', '90\t   Kenya', '91\t   Kiribati', '92\t"   Korea, North "', 
    '93\t"   Korea, South "', '94\t   Kuwait', '95\t   Kyrgyzstan', '96\t  Laos', '97\t   Latvia', 
    '98\t   Lebanon', '99\t   Lesotho', '100\t   Liberia', '101\t   Libya', '102\t   Liechtenstein', 
    '103\t   Lithuania', '104\t   Luxembourg', '105\t  Madagascar', '106\t   Malawi', '107\t   Malaysia', 
    '108\t   Maldives', '109\t   Mali', '110\t   Malta', '111\t   Marshall Islands', '112\t   Mauritania', 
    '113\t   Mauritius', '114\t   Mexico', '115\t"   Micronesia, Federated States of "', 
    '116\t   Moldova', '117\t   Monaco', '118\t   Mongolia', '119\t   Montenegro', '120\t   Morocco', 
    '121\t   Mozambique', '122\t   Myanmar', '123\t  Namibia', '124\t   Nauru', '125\t     Nepal', 
    '126\t   Netherlands', '127\t   New Zealand', '128\t   Nicaragua', '129\t   Niger', '130\t   Nigeria', 
    '131\t   North Macedonia', '132\t   Norway', '133\t  Oman', '134\t  Pakistan', '135\t   Palau', 
    '136\t   Palestine', '137\t   Panama', '138\t   Papua New Guinea', '139\t   Paraguay', 
    '140\t   Peru', '141\t   Philippines', '142\t   Poland', '143\t   Portugal', '144\t  Qatar', 
    '145\t  Romania', '146\t   Russia', '147\t   Rwanda', '148\t  Saint Kitts and Nevis', 
    '149\t   Saint Lucia', '150\t   Saint Vincent and the Grenadines', '151\t   Samoa', '152\t   San Marino', 
    '153\t   São Tomé and Príncipe', '154\t   Saudi Arabia', '155\t   Senegal', '156\t   Serbia', 
    '157\t   Seychelles', '158\t   Sierra Leone', '159\t   Singapore', '160\t   Slovakia', 
    '161\t   Slovenia', '162\t   Solomon Islands', '163\t   Somalia', '164\t   South Africa', 
    '165\t   South Sudan', '166\t   Spain', '167\t   Sri Lanka', '168\t   Sudan', '169\t   Suriname', 
    '170\t   Sweden', '171\t    Switzerland', '172\t   Syria', '173\t  Tajikistan', '174\t   Tanzania', 
    '175\t   Thailand', '176\t   Togo', '177\t   Tonga', '178\t   Trinidad and Tobago', '179\t   Tunisia', 
    '180\t   Turkey', '181\t   Turkmenistan', '182\t   Tuvalu', '183\t  Uganda', '184\t   Ukraine', 
    '185\t   United Arab Emirates', '186\t   United Kingdom', '187\t   United States', '188\t   Uruguay', 
    '189\t   Uzbekistan', '190\t  Vanuatu', '191\t    Vatican City (Holy See)', '192\t   Venezuela', 
    '193\t   Vietnam', '194\t  Yemen', '195\t  Zambia', '196\t   Zimbabwe', '197\t  Abkhazia', 
    '198\t   Artsakh', '199\t   Cook Islands', "200\t   Donetsk People's Republic", '201\t   Kosovo', 
    "202\t   Luhansk People's Republic", '203\t   Niue', '204\t   Northern Cyprus', 
    '205\t   Sahrawi Arab Democratic Republic', '206\t   Somaliland', '207\t   South Ossetia', 
    '208\t   Taiwan', '209\t   Transnistria'
]

# Clean the data: Separate the number and country name
country_dict = {}
for entry in country_list_raw:
    parts = entry.split('\t')
    number = parts[0].strip()  # Country number (e.g., '1')
    country_name = parts[1].strip().replace('"', '').replace('“', '').replace('”', '')  # Remove extra quotes and spaces
    country_dict[number] = country_name

# Convert the dictionary to a pandas DataFrame
df = pd.DataFrame(list(country_dict.items()), columns=["Index", "Country"])

# Display the entire DataFrame (list of 208 countries)
pd.set_option('display.max_rows', 208)  # Ensure that all rows are displayed
print(df)
# Out:
#     Index                           Country
# 0       1                       Afghanistan
# 1       2                           Albania
# 2       3                           Algeria
# 3       4                           Andorra
# 4       5                            Angola
# ..    ...                               ...
# 204   205  Sahrawi Arab Democratic Republic
# 205   206                        Somaliland
# 206   207                     South Ossetia
# 207   208                            Taiwan
# 208   209                      Transnistria
#
# [209 rows x 2 columns]

# %%
# Create a DataFrame with 'COUNTRIES' column
chars = pd.DataFrame(countries_list, columns=["Country"])

# Remove numbers and tabs from country names using regular expression
chars['Country'] = chars['Country'].apply(lambda x: re.sub(r'^\d+\t|\t', '', x).strip())


# Apply the operation to create a new column 'COUNTRIES_alias'
# If the country has a space, keep it as is (2 words). Otherwise, just return the name.
chars['Country_ALIAS'] = chars['Country'].apply(lambda x: x if ' ' not in x else x)

# Display the DataFrame
print(chars)
# Out:
#                               Country                     Country_ALIAS
# 0                        country_name                      country_name
# 1                         Afghanistan                       Afghanistan
# 2                             Albania                           Albania
# 3                             Algeria                           Algeria
# 4                             Andorra                           Andorra
# ..                                ...                               ...
# 205  Sahrawi Arab Democratic Republic  Sahrawi Arab Democratic Republic
# 206                        Somaliland                        Somaliland
# 207                     South Ossetia                     South Ossetia
# 208                            Taiwan                            Taiwan
# 209                      Transnistria                      Transnistria
#
# [210 rows x 2 columns]

# %%
# Function to filter out entities not of interest

def filter_entity(ent_list, chars):
       return [ent for ent in ent_list
                  if ent in list(chars['Country_ALIAS'])]

# %%
df_sentences['Country_entities'] = df_sentences['entities'].apply(lambda x: filter_entity(x, chars))

# %%
# Filter out sentences that don’t have any character entities

df_sentences_filtered = df_sentences[df_sentences['Country_entities'].map(len) > 0]

df_sentences_filtered.tail(10)
# Out:
#                                                sentence  \
# 1220  (", The, forgotten, violence, that, helped, In...
# 1225  (", Indian, Independence, Day, :, everything, ...
# 1234  (^, ", The, Philippines, ,, 1898â€“1946, |, US...
# 1265  (", Colonial, Cartographies, ,, Postcolonial, ...
# 1302  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1364  (", Selling, ", Operation, Passage, to, Freedo...
# 1395  (", Stuck, in, Endless, Preliminaries, :, Viet...
# 1661  (", Anti, -, American, Behavior, in, the, Midd...
# 1667  (The, Rise, of, China, and, India, :, A, New, ...
# 1668               (Singapore, :, World, Scientific, .)
#
#                                                entities   Country_entities
# 1220                                            [India]            [India]
# 1225  [Indian Independence Day, Partition between In...         [Pakistan]
# 1234  [Philippines, 1898â€“1946, US House of Represe...      [Philippines]
# 1265  [Colonial Cartographies, Postcolonial Borders,...      [Afghanistan]
# 1302  [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 1364  [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1395  [Stuck in Endless Preliminaries, Vietnam, the ...          [Vietnam]
# 1661  [Anti-American Behavior, the Middle East, a Fi...          [Lebanon]
# 1667                                 [India, New Asian]            [India]
# 1668                      [Singapore, World Scientific]        [Singapore]

# %%
# Make a copy of the dataframe to avoid the SettingWithCopyWarning
df_sentences_filtered = df_sentences_filtered.copy()

# Now, apply the transformation safely using .loc[]
df_sentences_filtered.loc[:, 'Country_entities'] = df_sentences_filtered['Country_entities'].apply(
    lambda x: [item.split()[0] for item in x]
)

# Print the updated DataFrame to verify
df_sentences_filtered.tail(10)  # Print the first few rows of the DataFrame
# Out:
#                                                sentence  \
# 1220  (", The, forgotten, violence, that, helped, In...
# 1225  (", Indian, Independence, Day, :, everything, ...
# 1234  (^, ", The, Philippines, ,, 1898â€“1946, |, US...
# 1265  (", Colonial, Cartographies, ,, Postcolonial, ...
# 1302  (The, Moldovans, :, Romania, ,, Russia, ,, and...
# 1364  (", Selling, ", Operation, Passage, to, Freedo...
# 1395  (", Stuck, in, Endless, Preliminaries, :, Viet...
# 1661  (", Anti, -, American, Behavior, in, the, Midd...
# 1667  (The, Rise, of, China, and, India, :, A, New, ...
# 1668               (Singapore, :, World, Scientific, .)
#
#                                                entities   Country_entities
# 1220                                            [India]            [India]
# 1225  [Indian Independence Day, Partition between In...         [Pakistan]
# 1234  [Philippines, 1898â€“1946, US House of Represe...      [Philippines]
# 1265  [Colonial Cartographies, Postcolonial Borders,...      [Afghanistan]
# 1302  [Moldovans, Romania, Russia, the Politics of C...  [Romania, Russia]
# 1364  [Thomas Dooley, the Religious Overtones of Ear...          [Vietnam]
# 1395  [Stuck in Endless Preliminaries, Vietnam, the ...          [Vietnam]
# 1661  [Anti-American Behavior, the Middle East, a Fi...          [Lebanon]
# 1667                                 [India, New Asian]            [India]
# 1668                      [Singapore, World Scientific]        [Singapore]

# %% [markdown]
# ## Creating Relationships

# %%
# Initialize the relationships list
relationships = []

# Loop through the DataFrame, considering each sentence and the next ones within the window size (5 sentences)
for i in range(len(df_sentences_filtered)):  # Loop through the DataFrame rows
    # Define the window's end index (i + 5, but it should not exceed the last index of the DataFrame)
    end_i = min(i + 5, len(df_sentences_filtered))

    # Extract the list of countries in the current window (from sentence i to end_i)
    Country_list = sum(df_sentences_filtered.loc[i:end_i, 'Country_entities'], [])

    # Remove consecutive duplicates from the list
    Country_unique = [Country_list[i] for i in range(len(Country_list)) 
                      if i == 0 or Country_list[i] != Country_list[i - 1]]

    # If there are at least two unique countries, create relationships between them
    if len(Country_unique) > 1:
        # Loop through the unique countries and create relationships between consecutive countries
        for idx in range(len(Country_unique) - 1):
            a = Country_unique[idx]
            b = Country_unique[idx + 1]
            relationships.append({"Source": a, "Target": b})

# Convert relationships to a DataFrame
relationships_df = pd.DataFrame(relationships)

# Display the first few rows
relationships_df.head(10)
# Out:
#     Source   Target
# 0   France  Austria
# 1  Austria  Hungary
# 2   France  Austria
# 3  Austria  Hungary
# 4  Hungary   Russia
# 5   France  Austria
# 6  Austria  Hungary
# 7  Hungary   Russia
# 8   Russia  Germany
# 9  Germany   Russia

# %%
relationship_df = pd.DataFrame(relationships)

relationship_df
# Out:
#       Source   Target
# 0     France  Austria
# 1    Austria  Hungary
# 2     France  Austria
# 3    Austria  Hungary
# 4    Hungary   Russia
# ..       ...      ...
# 226    Egypt     Iraq
# 227     Iraq     Iran
# 228    Egypt     Iraq
# 229     Iraq     Iran
# 230     Iraq     Iran
#
# [231 rows x 2 columns]

# %%
# Sort the cases with a- >b and b- >a
relationships_df = pd.DataFrame(np.sort(relationship_df.values, axis = 1), columns = relationship_df.columns)
relationships_df.head(5)
# Out:
#     Source   Target
# 0  Austria   France
# 1  Austria  Hungary
# 2  Austria   France
# 3  Austria  Hungary
# 4  Hungary   Russia

# %%
# Assuming your DataFrame has columns 'Source' and 'Target'
relationships_df["Value"] = 1  # Add a "value" column to count occurrences

# Group by 'Source' and 'Target', summing the 'value' column to count relationships
relationships_df = relationships_df.groupby(["Source", "Target"], sort=False, as_index=False).sum()

# Display the top 10 rows of the resulting DataFrame
relationships_df.head(10)
# Out:
#     Source   Target  Value
# 0  Austria   France      6
# 1  Austria  Hungary      6
# 2  Hungary   Russia      5
# 3  Germany   Russia     16
# 4  Germany  Ukraine     10
# 5  Austria  Germany     12
# 6  Germany    Italy      9
# 7   France   Poland     11
# 8   France  Germany     11
# 9  Germany   Poland     17

# %%
## Exporting to CSV

# %%
# Export the relationships DataFrame to a CSV file
relationships_df.to_csv('relationships.csv', index=False)

# Optional: Display a message confirming that the file was saved
print("relationships_df has been saved to 'relationships.csv'")
# Out:
# relationships_df has been saved to 'relationships.csv'
